# %% [markdown]
# ## Atividade01/ Etapa02 - Python

# %% [markdown]
# Numpy arrays e pandas Dataframes
# Open and export files
# Conditional Statements
# Loops em Python
# Functions - def

# %% [markdown]
# ## 1.1 Numpy arrays

# %%
import numpy as np

# Criando um vetor de dados aleatórios
data = np.random.rand(1000,2)

# Verificando o tamanho do vetor
print(data.shape)
print(np.size(data))

# Print de uma amostra dos dados
print(data[0:10])
print(data[0:10].shape)

# %%
# Usando Monte-Carlo
dataMax = 1000
dataMin = 10
data = (dataMax - dataMin)*data + dataMin
print(data[0:10])
# Out:
# [[700.09184614 255.5375873 ]
#  [582.4163604  363.96740764]
#  [ 98.97903534 782.86338003]
#  [827.30545658 722.14343522]
#  [957.55787671 922.31651179]
#  [579.286318   361.92695754]
#  [409.29658561 465.66770859]
#  [724.11977301  39.70975739]
#  [784.30500208 205.61540809]
#  [275.24216062 813.33335254]]

# %%
#instalar matplotlib
import matplotlib.pyplot as plt

fig, ax = plt.subplots(3)
ax[0].plot(data)
ax[1].plot(data[:,0])
ax[2].plot(data[:,1])
print(type(data))
# Out:
# <class 'numpy.ndarray'>

# %%
data3d = np.sin(np.random.rand(1000,1000))
print(data3d)
# Out:
# [[0.62371735 0.29209292 0.83717047 ... 0.6165306  0.57515886 0.50578187]
#  [0.26475922 0.15232803 0.10284071 ... 0.78409778 0.36705678 0.57798232]
#  [0.42248175 0.4932748  0.82148841 ... 0.49056682 0.43027799 0.75792162]
#  ...
#  [0.62543855 0.68723703 0.381799   ... 0.62306396 0.68390028 0.23923532]
#  [0.03752929 0.06820684 0.05141096 ... 0.07672921 0.78218504 0.78318715]
#  [0.25693889 0.17503953 0.64363592 ... 0.55143019 0.73952553 0.80337243]]

# %%
fig2, ax2 = plt.subplots()
ax2.pcolor(data3d)

# %%
dtime = np.arange(np.datetime64("2022-01-01"), np.datetime64("2023-01-01"), np.timedelta64(1, "h"))
print(dtime[1:10])
print(dtime.shape)
print(type(dtime))
# Out:
# ['2022-01-01T01' '2022-01-01T02' '2022-01-01T03' '2022-01-01T04'
#  '2022-01-01T05' '2022-01-01T06' '2022-01-01T07' '2022-01-01T08'
#  '2022-01-01T09']
# (8760,)
# <class 'numpy.ndarray'>

# %% [markdown]
# ## Import Pandas

# %%
#instalar pandas 
import pandas as pd

# Criando um dataframe
df = pd.DataFrame()

# %%
df['datetime'] = dtime

# %%
# Criando uma coluna random dentro do dataframe df
df['random'] = np.random.rand(df.shape[0])

# %%
df['random'][1:10]
# Out:
# 1    0.300797
# 2    0.440396
# 3    0.697049
# 4    0.912707
# 5    0.444232
# 6    0.874192
# 7    0.587935
# 8    0.635776
# 9    0.294190
# Name: random, dtype: float64

# %%
# Indexação
df.iloc[:,0]
# Out:
# 0      2022-01-01 00:00:00
# 1      2022-01-01 01:00:00
# 2      2022-01-01 02:00:00
# 3      2022-01-01 03:00:00
# 4      2022-01-01 04:00:00
#                ...
# 8755   2022-12-31 19:00:00
# 8756   2022-12-31 20:00:00
# 8757   2022-12-31 21:00:00
# 8758   2022-12-31 22:00:00
# 8759   2022-12-31 23:00:00
# Name: datetime, Length: 8760, dtype: datetime64[s]

# %%
# Colocando o datetime como index
df = df.set_index(df['datetime'])
df
# Out:
#                                datetime    random
# datetime
# 2022-01-01 00:00:00 2022-01-01 00:00:00  0.448542
# 2022-01-01 01:00:00 2022-01-01 01:00:00  0.300797
# 2022-01-01 02:00:00 2022-01-01 02:00:00  0.440396
# 2022-01-01 03:00:00 2022-01-01 03:00:00  0.697049
# 2022-01-01 04:00:00 2022-01-01 04:00:00  0.912707
# ...                                 ...       ...
# 2022-12-31 19:00:00 2022-12-31 19:00:00  0.235000
# 2022-12-31 20:00:00 2022-12-31 20:00:00  0.899863
# 2022-12-31 21:00:00 2022-12-31 21:00:00  0.976029
# 2022-12-31 22:00:00 2022-12-31 22:00:00  0.161271
# 2022-12-31 23:00:00 2022-12-31 23:00:00  0.186764
#
# [8760 rows x 2 columns]

# %%
# Criando colunas com ano, mês e dia
df['year'] = df.index.year
df['month'] = df.index.month
df['day'] = df.index.day

# %%
tt = np.arange(0,df.shape[0],1)
print(tt.shape)
df['sazonal'] = (np.cos(tt/(360*4)))
df['timeSeries'] = 10*df['sazonal']+df['random']
#df['sazonal'].plot()
df['timeSeries'].plot(color='red')
# Out:
# (8760,)
# <Axes: xlabel='datetime'>

# %%
df
# Out:
#                                datetime    random  year  month  day   sazonal  \
# datetime
# 2022-01-01 00:00:00 2022-01-01 00:00:00  0.448542  2022      1    1  1.000000
# 2022-01-01 01:00:00 2022-01-01 01:00:00  0.300797  2022      1    1  1.000000
# 2022-01-01 02:00:00 2022-01-01 02:00:00  0.440396  2022      1    1  0.999999
# 2022-01-01 03:00:00 2022-01-01 03:00:00  0.697049  2022      1    1  0.999998
# 2022-01-01 04:00:00 2022-01-01 04:00:00  0.912707  2022      1    1  0.999996
# ...                                 ...       ...   ...    ...  ...       ...
# 2022-12-31 19:00:00 2022-12-31 19:00:00  0.235000  2022     12   31  0.979401
# 2022-12-31 20:00:00 2022-12-31 20:00:00  0.899863  2022     12   31  0.979541
# 2022-12-31 21:00:00 2022-12-31 21:00:00  0.976029  2022     12   31  0.979680
# 2022-12-31 22:00:00 2022-12-31 22:00:00  0.161271  2022     12   31  0.979819
# 2022-12-31 23:00:00 2022-12-31 23:00:00  0.186764  2022     12   31  0.979958
#
#                      timeSeries
# datetime
# 2022-01-01 00:00:00   10.448542
# 2022-01-01 01:00:00   10.300794
# 2022-01-01 02:00:00   10.440386
# 2022-01-01 03:00:00   10.697027
# 2022-01-01 04:00:00   10.912669
# ...                         ...
# 2022-12-31 19:00:00   10.029007
# 2022-12-31 20:00:00   10.695271
# 2022-12-31 21:00:00   10.772831
# 2022-12-31 22:00:00    9.959464
# 2022-12-31 23:00:00    9.986343
#
# [8760 rows x 7 columns]

# %%
# Salvar meu dataframe
# Prestar atenção nas barras 
df.to_csv(r'C:\Users\PC\Documents\GitHub\ENS5173_202401/noise_2022.csv')

# %%
# Criando uma função
def noiseCreation(path, year):
    """Esta função cria um ruido com sazonalidade.
    Inputs:
        path = asdasdas
        year = asdasdasdas

    Criado por Leonardo
    """
    
    # Criando um dataframe
    df = pd.DataFrame()
    
    # Criando vertor temporal
    dtime = np.arange(np.datetime64(str(year)+"-01-01"), np.datetime64(str(year+1)+"-01-01"), np.timedelta64(1, "h"))
    
    # Monstrando um dataframe
    df['datetime'] = dtime
        
    # Datetime como index do dataframe
    df = df.set_index(df['datetime'])
    
    # Criando colunas com ano, mês e dia
    df['year'] = df.index.year
    df['month'] = df.index.month
    df['day'] = df.index.day
    
    # Crio uma coluna random
    df['random'] = np.random.rand(df.shape[0])
    
    # Adicionar sazonalidade
    tt = np.arange(0,df.shape[0],1)
    print(tt.shape)
    df['sazonal'] = (np.cos(tt/(360*4)))
    df['timeSeries'] = 10*df['sazonal']+df['random']
    #df['sazonal'].plot()
    df['timeSeries'].plot(color='red')
    df.to_csv(path+'/noise_'+str(year)+'.csv')
    
    return df

# %%
path = 'C:/Users/PC/Documents/GitHub/ENS5173_202401/'
df2 = noiseCreation(path,2050)
# Out:
# (8760,)

# %%
# Primeira opção de loop
for ii in range(2002,2010):
    print(ii)
    df = noiseCreation(path,ii)
# Out:
# 2002
# (8760,)
# 2003
# (8760,)
# 2004
# (8784,)
# 2005
# (8760,)
# 2006
# (8760,)
# 2007
# (8760,)
# 2008
# (8784,)
# 2009
# (8760,)

# %%
df
# Out:
#                                datetime  year  month  day    random   sazonal  \
# datetime
# 2009-01-01 00:00:00 2009-01-01 00:00:00  2009      1    1  0.761827  1.000000
# 2009-01-01 01:00:00 2009-01-01 01:00:00  2009      1    1  0.913570  1.000000
# 2009-01-01 02:00:00 2009-01-01 02:00:00  2009      1    1  0.948318  0.999999
# 2009-01-01 03:00:00 2009-01-01 03:00:00  2009      1    1  0.678021  0.999998
# 2009-01-01 04:00:00 2009-01-01 04:00:00  2009      1    1  0.295123  0.999996
# ...                                 ...   ...    ...  ...       ...       ...
# 2009-12-31 19:00:00 2009-12-31 19:00:00  2009     12   31  0.403414  0.979401
# 2009-12-31 20:00:00 2009-12-31 20:00:00  2009     12   31  0.537679  0.979541
# 2009-12-31 21:00:00 2009-12-31 21:00:00  2009     12   31  0.650567  0.979680
# 2009-12-31 22:00:00 2009-12-31 22:00:00  2009     12   31  0.196217  0.979819
# 2009-12-31 23:00:00 2009-12-31 23:00:00  2009     12   31  0.379960  0.979958
#
#                      timeSeries
# datetime
# 2009-01-01 00:00:00   10.761827
# 2009-01-01 01:00:00   10.913567
# 2009-01-01 02:00:00   10.948308
# 2009-01-01 03:00:00   10.677999
# 2009-01-01 04:00:00   10.295084
# ...                         ...
# 2009-12-31 19:00:00   10.197422
# 2009-12-31 20:00:00   10.333086
# 2009-12-31 21:00:00   10.447369
# 2009-12-31 22:00:00    9.994410
# 2009-12-31 23:00:00   10.179539
#
# [8760 rows x 7 columns]

# %%
anos = [2001,2030,2032,2053,2060]

for ano in anos:
    print(ano)
    if ano > 2030:
        df = noiseCreation(path,ano)
# Out:
# 2001
# 2030
# 2032
# (8784,)
# 2053
# (8760,)
# 2060
# (8784,)

# %%
import os
files = os.listdir(path)
print(files)

allData = []
for file in files:
    if file.endswith('.csv'):
        print(file)
        data = pd.read_csv(path+'/'+file)
        allData.append(data)
# Out:
# ['.git', '.gitignore', 'Aula02.ipynb', 'desktop.ini', 'noise_2002.csv', 'noise_2003.csv', 'noise_2004.csv', 'noise_2005.csv', 'noise_2006.csv', 'noise_2007.csv', 'noise_2008.csv', 'noise_2009.csv', 'noise_2022.csv', 'noise_2032.csv', 'noise_2050.csv', 'noise_2053.csv', 'noise_2060.csv', 'README.md', 'Scripts', 'Untitled.ipynb', 'venv']
# noise_2002.csv
# noise_2003.csv
# noise_2004.csv
# noise_2005.csv
# noise_2006.csv
# noise_2007.csv
# noise_2008.csv
# noise_2009.csv
# noise_2022.csv
# noise_2032.csv
# noise_2050.csv
# noise_2053.csv
# noise_2060.csv

# %%
allDataDf = pd.concat(allData)

# %%
allDataDf
# Out:
#                  datetime           datetime.1  year  month  day    random  \
# 0     2002-01-01 00:00:00  2002-01-01 00:00:00  2002      1    1  0.368656
# 1     2002-01-01 01:00:00  2002-01-01 01:00:00  2002      1    1  0.397741
# 2     2002-01-01 02:00:00  2002-01-01 02:00:00  2002      1    1  0.999509
# 3     2002-01-01 03:00:00  2002-01-01 03:00:00  2002      1    1  0.666097
# 4     2002-01-01 04:00:00  2002-01-01 04:00:00  2002      1    1  0.855659
# ...                   ...                  ...   ...    ...  ...       ...
# 8779  2060-12-31 19:00:00  2060-12-31 19:00:00  2060     12   31  0.953632
# 8780  2060-12-31 20:00:00  2060-12-31 20:00:00  2060     12   31  0.402024
# 8781  2060-12-31 21:00:00  2060-12-31 21:00:00  2060     12   31  0.578550
# 8782  2060-12-31 22:00:00  2060-12-31 22:00:00  2060     12   31  0.199643
# 8783  2060-12-31 23:00:00  2060-12-31 23:00:00  2060     12   31  0.006536
#
#        sazonal  timeSeries
# 0     1.000000   10.368656
# 1     1.000000   10.397738
# 2     0.999999   10.999500
# 3     0.999998   10.666075
# 4     0.999996   10.855621
# ...        ...         ...
# 8779  0.982630   10.779932
# 8780  0.982759   10.229610
# 8781  0.982887   10.407418
# 8782  0.983014   10.029788
# 8783  0.983142    9.837953
#
# [113976 rows x 8 columns]

# %%
plt.plot(allDataDf['datetime'],allDataDf['timeSeries'])
